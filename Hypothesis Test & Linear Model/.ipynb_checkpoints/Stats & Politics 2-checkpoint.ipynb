# %% [markdown]
# # US Presidential Election: Hypothesis Test & Predictive Modeling

# %% [markdown]
# This project builds on the results of the previous one *US Presidential Election: Data Cleaning & EDA* to create
# a predictive model. First, correlation of various demographics information with party vote shares are evaluated. Then,  difference of vote shares between election cycles are statistically tested using approperiate test method. Finally,

# %%
import numpy as np
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data_clean.csv')
data.head()
# Out:
#    Unnamed: 0     State   Fips                    County  Precincts    Votes  \
# 0           0  Arkansas   5043     Drew County, Arkansas       17.0   6590.0
# 1           1  Arkansas   5087  Madison County, Arkansas       20.0   6829.0
# 2           2   Georgia  13159    Jasper County, Georgia        3.0   6016.0
# 3           3  Colorado   8037    Eagle County, Colorado       30.0  22611.0
# 4           4   Georgia  13091     Dodge County, Georgia       16.0   6995.0
#
#    Less Than High School Diploma  At Least High School Diploma  \
# 0                           19.4                          80.6
# 1                           24.2                          75.8
# 2                           21.7                          78.3
# 3                           12.8                          87.2
# 4                           23.1                          76.9
#
#    At Least Bachelors's Degree  Graduate Degree  ...  Teen.births  \
# 0                         19.4              5.7  ...         47.7
# 1                         13.4              4.1  ...         49.0
# 2                         13.3              5.6  ...         54.1
# 3                         45.9             11.7  ...         41.3
# 4                         13.8              4.8  ...         64.0
#
#    Children.in.single.parent.households  Adult.smoking  Adult.obesity  \
# 0                                 0.429          0.181          0.323
# 1                                 0.179          0.304          0.328
# 2                                 0.381          0.210          0.298
# 3                                 0.204          0.095          0.132
# 4                                 0.453          0.189          0.358
#
#    Diabetes  Sexually.transmitted.infections  Uninsured  Unemployment  \
# 0     0.126                            747.3      0.197         0.108
# 1     0.135                            247.2      0.239         0.053
# 2     0.118                            324.1      0.239         0.096
# 3     0.036                            190.9      0.230         0.081
# 4     0.153                            497.9      0.208         0.115
#
#    Violent.crime  Injury.deaths
# 0         449.02           82.0
# 1         245.83           96.8
# 2         205.60           71.6
# 3         123.88           42.9
# 4         477.48           79.4
#
# [5 rows x 44 columns]

# %%
vote = pd.read_csv('votes_clean.csv')
vote.head()
# Out:
#    Unnamed: 0  Democrats_12(Votes)  Republicans_12(Votes)  \
# 0           0               2630.0                 3887.0
# 1           1               2099.0                 4263.0
# 2           2               1845.0                 4136.0
# 3           3              12792.0                 9411.0
# 4           4               2442.0                 5214.0
#
#    Democrats_16(Votes)  Republicans_16(Votes)  Democrats12_VoteShare  \
# 0               2364.0                 3967.0                  40.36
# 1               1587.0                 4917.0                  32.99
# 2               1544.0                 4353.0                  30.85
# 3              12652.0                 8153.0                  57.61
# 4               1836.0                 5021.0                  31.90
#
#    Republicans12_VoteShare  Democrats16_VoteShare  Republicans16_VoteShare
# 0                    59.64                  37.34                    62.66
# 1                    67.01                  24.40                    75.60
# 2                    69.15                  26.18                    73.82
# 3                    42.39                  60.81                    39.19
# 4                    68.10                  26.78                    73.22

# %%
data_vote = pd.merge(data, vote, on = 'Unnamed: 0')
data_vote.head(5)
# Out:
#    Unnamed: 0     State   Fips                    County  Precincts    Votes  \
# 0           0  Arkansas   5043     Drew County, Arkansas       17.0   6590.0
# 1           1  Arkansas   5087  Madison County, Arkansas       20.0   6829.0
# 2           2   Georgia  13159    Jasper County, Georgia        3.0   6016.0
# 3           3  Colorado   8037    Eagle County, Colorado       30.0  22611.0
# 4           4   Georgia  13091     Dodge County, Georgia       16.0   6995.0
#
#    Less Than High School Diploma  At Least High School Diploma  \
# 0                           19.4                          80.6
# 1                           24.2                          75.8
# 2                           21.7                          78.3
# 3                           12.8                          87.2
# 4                           23.1                          76.9
#
#    At Least Bachelors's Degree  Graduate Degree  ...  Violent.crime  \
# 0                         19.4              5.7  ...         449.02
# 1                         13.4              4.1  ...         245.83
# 2                         13.3              5.6  ...         205.60
# 3                         45.9             11.7  ...         123.88
# 4                         13.8              4.8  ...         477.48
#
#    Injury.deaths  Democrats_12(Votes)  Republicans_12(Votes)  \
# 0           82.0               2630.0                 3887.0
# 1           96.8               2099.0                 4263.0
# 2           71.6               1845.0                 4136.0
# 3           42.9              12792.0                 9411.0
# 4           79.4               2442.0                 5214.0
#
#    Democrats_16(Votes)  Republicans_16(Votes)  Democrats12_VoteShare  \
# 0               2364.0                 3967.0                  40.36
# 1               1587.0                 4917.0                  32.99
# 2               1544.0                 4353.0                  30.85
# 3              12652.0                 8153.0                  57.61
# 4               1836.0                 5021.0                  31.90
#
#    Republicans12_VoteShare  Democrats16_VoteShare  Republicans16_VoteShare
# 0                    59.64                  37.34                    62.66
# 1                    67.01                  24.40                    75.60
# 2                    69.15                  26.18                    73.82
# 3                    42.39                  60.81                    39.19
# 4                    68.10                  26.78                    73.22
#
# [5 rows x 52 columns]

# %%
data_vote['Republicans12_VoteShare']
data_vote.iloc[:,3]
#stats.pearsonr(data_vote.iloc[:,1], data_vote['Republicans12_VoteShare'])
# Out:
# 0           Drew County, Arkansas
# 1        Madison County, Arkansas
# 2          Jasper County, Georgia
# 3          Eagle County, Colorado
# 4           Dodge County, Georgia
#                   ...
# 3136          Butler County, Ohio
# 3137           Logan County, Ohio
# 3138          Lorain County, Ohio
# 3139    Cherokee County, Oklahoma
# 3140    Cimarron County, Oklahoma
# Name: County, Length: 3141, dtype: object

# %%
stats.pearsonr(data_vote.iloc[:,0], data_vote['Republicans12_VoteShare'])[0]
# Out:
# 0.0053615713045454295

# %%
data=[]
for i in range(4,data_vote.shape[1]):  
    data.append([data_vote.columns[i], 
    stats.pearsonr(data_vote.iloc[:,i], data_vote['Republicans12_VoteShare'])[0], 
    stats.pearsonr(data_vote.iloc[:,i], data_vote['Republicans16_VoteShare'])[0],
    stats.pearsonr(data_vote.iloc[:,i], data_vote['Republicans12_VoteShare'])[1], 
    stats.pearsonr(data_vote.iloc[:,i], data_vote['Republicans16_VoteShare'])[1]])
df_corr=pd.DataFrame(data,columns = ['Demographic info', '12 Correlation', '16 Correlation', '12 P-value', '16 P-value'])

df_corr
# Out:
#                                      Demographic info  12 Correlation  \
# 0                                           Precincts       -0.266277
# 1                                               Votes       -0.302003
# 2                       Less Than High School Diploma        0.049446
# 3                        At Least High School Diploma       -0.047965
# 4                         At Least Bachelors's Degree       -0.303216
# 5                                     Graduate Degree       -0.369278
# 6                                   School Enrollment       -0.132662
# 7                                Median Earnings 2010       -0.116098
# 8                       White (Not Latino) Population        0.437955
# 9                         African American Population       -0.392567
# 10                         Native American Population       -0.104147
# 11                          Asian American Population       -0.304657
# 12                                Other Race or Races       -0.092667
# 13                                  Latino Population       -0.096990
# 14                 Children Under 6 Living in Poverty       -0.115787
# 15              Adults 65 and Older Living in Poverty       -0.071574
# 16                                   Total Population       -0.270416
# 17   Preschool.Enrollment.Ratio.enrolled.ages.3.and.4       -0.271683
# 18       Poverty.Rate.below.federal.poverty.threshold       -0.164104
# 19                                   Gini.Coefficient       -0.217965
# 20  Child.Poverty.living.in.families.below.the.pov...       -0.135144
# 21    Management.professional.and.related.occupations       -0.115862
# 22                                Service.occupations       -0.272234
# 23                       Sales.and.office.occupations       -0.195823
# 24           Farming.fishing.and.forestry.occupations        0.238850
# 25  Construction.extraction.maintenance.and.repair...        0.345326
# 26  Production.transportation.and.material.moving....        0.098097
# 27                                   SIRE_homogeneity        0.281648
# 28                                         median_age        0.205948
# 29                                    Low.birthweight       -0.153740
# 30                                        Teen.births        0.086154
# 31               Children.in.single.parent.households       -0.427325
# 32                                      Adult.smoking        0.124789
# 33                                      Adult.obesity        0.064553
# 34                                           Diabetes        0.075749
# 35                    Sexually.transmitted.infections       -0.414017
# 36                                          Uninsured        0.258432
# 37                                       Unemployment       -0.328212
# 38                                      Violent.crime       -0.299639
# 39                                      Injury.deaths        0.213762
# 40                                Democrats_12(Votes)       -0.329763
# 41                              Republicans_12(Votes)       -0.224541
# 42                                Democrats_16(Votes)       -0.326821
# 43                              Republicans_16(Votes)       -0.226416
# 44                              Democrats12_VoteShare       -1.000000
# 45                            Republicans12_VoteShare        1.000000
# 46                              Democrats16_VoteShare       -0.943883
# 47                            Republicans16_VoteShare        0.943883
#
#     16 Correlation     12 P-value     16 P-value
# 0        -0.330111   3.963033e-52   9.712766e-81
# 1        -0.395448   3.047631e-67  4.407163e-118
# 2         0.058951   5.575399e-03   9.482711e-04
# 3        -0.054349   7.174521e-03   2.311376e-03
# 4        -0.464169   8.532572e-68  1.233182e-167
# 5        -0.517054  4.517001e-102  2.508930e-214
# 6        -0.167999   8.327733e-14   2.564286e-21
# 7        -0.192509   6.748051e-11   1.332676e-27
# 8         0.552828  2.284088e-147  6.294776e-251
# 9        -0.461468  3.012613e-116  1.829538e-165
# 10       -0.065390   4.901094e-09   2.452160e-04
# 11       -0.394287   1.867132e-68  2.430479e-117
# 12       -0.107921   1.965146e-07   1.330441e-09
# 13       -0.197589   5.138842e-08   5.121962e-29
# 14       -0.078237   7.588126e-11   1.134729e-05
# 15       -0.034175   5.947301e-05   5.547691e-02
# 16       -0.351670   9.109055e-54   4.185178e-92
# 17       -0.304127   2.834523e-54   3.270219e-68
# 18       -0.143162   2.116223e-20   7.515503e-16
# 19       -0.289031   4.313520e-35   1.693777e-61
# 20       -0.105214   2.826895e-14   3.405106e-09
# 21       -0.232779   7.375555e-11   6.475682e-40
# 22       -0.237250   1.702239e-54   1.936354e-41
# 23       -0.265829   1.606481e-28   5.934568e-52
# 24        0.236012   5.416730e-42   5.153149e-41
# 25        0.363026   1.149040e-88   1.843745e-98
# 26        0.232372   3.610349e-08   8.878792e-40
# 27        0.438292   2.326053e-58  1.285906e-147
# 28        0.314474   1.972174e-31   4.739540e-73
# 29       -0.190540   4.537714e-18   4.600571e-27
# 30        0.077503   1.327741e-06   1.371119e-05
# 31       -0.421455  1.210057e-139  1.700415e-135
# 32        0.235213   2.243894e-12   9.669323e-41
# 33        0.154736   2.943815e-04   2.751316e-18
# 34        0.129020   2.140213e-05   3.918927e-13
# 35       -0.468603  2.344544e-130  3.045264e-171
# 36        0.168061   4.205681e-49   2.478017e-21
# 37       -0.300371   8.815779e-80   1.671080e-66
# 38       -0.370263   3.573177e-66  1.197687e-102
# 39        0.274245   8.716827e-34   2.617968e-55
# 40       -0.404322   1.455930e-80  7.510486e-124
# 41       -0.330903   3.437932e-37   3.852292e-81
# 42       -0.408885   4.396860e-79  6.931083e-127
# 43       -0.327154   8.423909e-38   2.994161e-79
# 44       -0.943883   0.000000e+00   0.000000e+00
# 45        0.943883   0.000000e+00   0.000000e+00
# 46       -1.000000   0.000000e+00   0.000000e+00
# 47        1.000000   0.000000e+00   0.000000e+00

# %%
summary=lm.summary()
coef_df=pd.DataFrame(data=summary.tables[1].data[1:], columns=summary.tables[1].data[0])
coef_df['coef'] = coef_df['coef'].astype(float)
coef_df['abs_coef'] = np.abs(coef_df['coef']) 
coef_by_mag = coef_df.sort_values(by='abs_coef', ascending=False)
coef_by_mag
# Out:
#                                                              coef    std err  \
# 0                                               const -182.274200    367.339
# 34                                           Diabetes   86.421000     11.880
# 36                                          Uninsured   81.820500      4.224
# 37                                       Unemployment  -77.182800      6.272
# 29                                    Low.birthweight   57.012300     10.826
# 31               Children.in.single.parent.households  -26.972000      2.387
# 27                                   SIRE_homogeneity  -22.117900      1.647
# 19                                   Gini.Coefficient   12.078800      5.331
# 33                                      Adult.obesity    3.508200      5.734
# 21    Management.professional.and.related.occupations    1.910700      2.549
# 25  Construction.extraction.maintenance.and.repair...    1.701100      2.548
# 24           Farming.fishing.and.forestry.occupations    1.694100      2.549
# 23                       Sales.and.office.occupations    1.590300      2.548
# 26  Production.transportation.and.material.moving....    1.463000      2.549
# 22                                Service.occupations    1.311400      2.549
# 9                       White (Not Latino) Population    1.264000      2.659
# 6                                     Graduate Degree   -0.752600      0.101
# 11                         Native American Population    0.702500      2.659
# 32                                      Adult.smoking   -0.688000      2.962
# 12                          Asian American Population    0.648800      2.660
# 14                                  Latino Population    0.633400      2.659
# 13                                Other Race or Races    0.613800      2.661
# 5                         At Least Bachelors's Degree   -0.569200      0.060
# 10                        African American Population    0.497400      2.659
# 18       Poverty.Rate.below.federal.poverty.threshold   -0.457900      0.077
# 28                                         median_age   -0.395400      0.043
# 20  Child.Poverty.living.in.families.below.the.pov...    0.118600      0.051
# 30                                        Teen.births    0.109900      0.014
# 7                                   School Enrollment    0.025600      0.031
# 39                                      Injury.deaths    0.016900      0.008
# 15                 Children Under 6 Living in Poverty   -0.011600      0.025
# 3                       Less Than High School Diploma   -0.002200      0.078
# 38                                      Violent.crime   -0.002200      0.001
# 4                        At Least High School Diploma   -0.001800      0.072
# 17   Preschool.Enrollment.Ratio.enrolled.ages.3.and.4    0.001400      0.010
# 1                                           Precincts   -0.001100      0.002
# 35                    Sexually.transmitted.infections   -0.000800      0.001
# 2                                               Votes   -0.000032   5.42e-06
# 8                                Median Earnings 2010   -0.000031   4.93e-05
# 16                                   Total Population    0.000008   2.15e-06
#
#             t   P>|t|     [0.025     0.975]    abs_coef
# 0      -0.496   0.620   -902.526    537.977  182.274200
# 34      7.274   0.000     63.127    109.715   86.421000
# 36     19.372   0.000     73.539     90.102   81.820500
# 37    -12.307   0.000    -89.480    -64.886   77.182800
# 29      5.266   0.000     35.786     78.239   57.012300
# 31    -11.300   0.000    -31.652    -22.292   26.972000
# 27    -13.430   0.000    -25.347    -18.889   22.117900
# 19      2.266   0.024      1.627     22.531   12.078800
# 33      0.612   0.541     -7.735     14.751    3.508200
# 21      0.750   0.454     -3.087      6.908    1.910700
# 25      0.668   0.505     -3.296      6.698    1.701100
# 24      0.665   0.506     -3.304      6.692    1.694100
# 23      0.624   0.533     -3.405      6.586    1.590300
# 26      0.574   0.566     -3.534      6.460    1.463000
# 22      0.515   0.607     -3.686      6.309    1.311400
# 9       0.475   0.635     -3.949      6.477    1.264000
# 6      -7.448   0.000     -0.951     -0.554    0.752600
# 11      0.264   0.792     -4.511      5.916    0.702500
# 32     -0.232   0.816     -6.496      5.120    0.688000
# 12      0.244   0.807     -4.566      5.864    0.648800
# 14      0.238   0.812     -4.581      5.847    0.633400
# 13      0.231   0.818     -4.604      5.832    0.613800
# 5      -9.551   0.000     -0.686     -0.452    0.569200
# 10      0.187   0.852     -4.715      5.710    0.497400
# 18     -5.984   0.000     -0.608     -0.308    0.457900
# 28     -9.128   0.000     -0.480     -0.310    0.395400
# 20      2.343   0.019      0.019      0.218    0.118600
# 30      8.065   0.000      0.083      0.137    0.109900
# 7       0.822   0.411     -0.035      0.087    0.025600
# 39      2.090   0.037      0.001      0.033    0.016900
# 15     -0.465   0.642     -0.060      0.037    0.011600
# 3      -0.029   0.977     -0.155      0.150    0.002200
# 38     -2.594   0.010     -0.004     -0.001    0.002200
# 4      -0.025   0.980     -0.142      0.139    0.001800
# 17      0.141   0.888     -0.018      0.021    0.001400
# 1      -0.548   0.584     -0.005      0.003    0.001100
# 35     -0.777   0.437     -0.003      0.001    0.000800
# 2      -5.934   0.000  -4.28e-05  -2.16e-05    0.000032
# 8      -0.634   0.526     -0.000   6.54e-05    0.000031
# 16      3.705   0.000   3.74e-06   1.22e-05    0.000008

# %%
stats.ttest_ind(data_vote['Republicans12_VoteShare'], data_vote['Republicans16_VoteShare'])
# Out:
# Ttest_indResult(statistic=-15.251111207856784, pvalue=1.348580485251551e-51)

# %%
lm = sm.OLS(data_vote['Republicans16_VoteShare'], 
            sm.add_constant(data_vote.drop(['Unnamed: 0', 'State', 'Fips', 'County', 'Adults 65 and Older Living in Poverty',           
                                            'Democrats_12(Votes)', 'Republicans_12(Votes)', 
                                            'Democrats_16(Votes)', 'Republicans_16(Votes)',                                                                                  
                                            'Democrats12_VoteShare', 'Republicans12_VoteShare',                                                                                 
                                            'Democrats16_VoteShare', 'Republicans16_VoteShare'], axis = 1))).fit()
lm.summary()
# Out:
# C:\Users\arali\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Republicans16_VoteShare   R-squared:                       0.800
# Model:                                 OLS   Adj. R-squared:                  0.797
# Method:                      Least Squares   F-statistic:                     317.5
# Date:                     Thu, 30 Jan 2020   Prob (F-statistic):               0.00
# Time:                             16:34:37   Log-Likelihood:                -10641.
# No. Observations:                     3141   AIC:                         2.136e+04
# Df Residuals:                         3101   BIC:                         2.160e+04
# Df Model:                               39
# Covariance Type:                 nonrobust
# ==============================================================================================================================
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# const                                                       -182.2742    367.339     -0.496      0.620    -902.526     537.977
# Precincts                                                     -0.0011      0.002     -0.548      0.584      -0.005       0.003
# Votes                                                      -3.219e-05   5.42e-06     -5.934      0.000   -4.28e-05   -2.16e-05
# Less Than High School Diploma                                 -0.0022      0.078     -0.029      0.977      -0.155       0.150
# At Least High School Diploma                                  -0.0018      0.072     -0.025      0.980      -0.142       0.139
# At Least Bachelors's Degree                                   -0.5692      0.060     -9.551      0.000      -0.686      -0.452
# Graduate Degree                                               -0.7526      0.101     -7.448      0.000      -0.951      -0.554
# School Enrollment                                              0.0256      0.031      0.822      0.411      -0.035       0.087
# Median Earnings 2010                                       -3.128e-05   4.93e-05     -0.634      0.526      -0.000    6.54e-05
# White (Not Latino) Population                                  1.2640      2.659      0.475      0.635      -3.949       6.477
# African American Population                                    0.4974      2.659      0.187      0.852      -4.715       5.710
# Native American Population                                     0.7025      2.659      0.264      0.792      -4.511       5.916
# Asian American Population                                      0.6488      2.660      0.244      0.807      -4.566       5.864
# Other Race or Races                                            0.6138      2.661      0.231      0.818      -4.604       5.832
# Latino Population                                              0.6334      2.659      0.238      0.812      -4.581       5.847
# Children Under 6 Living in Poverty                            -0.0116      0.025     -0.465      0.642      -0.060       0.037
# Total Population                                            7.952e-06   2.15e-06      3.705      0.000    3.74e-06    1.22e-05
# Preschool.Enrollment.Ratio.enrolled.ages.3.and.4               0.0014      0.010      0.141      0.888      -0.018       0.021
# Poverty.Rate.below.federal.poverty.threshold                  -0.4579      0.077     -5.984      0.000      -0.608      -0.308
# Gini.Coefficient                                              12.0788      5.331      2.266      0.024       1.627      22.531
# Child.Poverty.living.in.families.below.the.poverty.line        0.1186      0.051      2.343      0.019       0.019       0.218
# Management.professional.and.related.occupations                1.9107      2.549      0.750      0.454      -3.087       6.908
# Service.occupations                                            1.3114      2.549      0.515      0.607      -3.686       6.309
# Sales.and.office.occupations                                   1.5903      2.548      0.624      0.533      -3.405       6.586
# Farming.fishing.and.forestry.occupations                       1.6941      2.549      0.665      0.506      -3.304       6.692
# Construction.extraction.maintenance.and.repair.occupations     1.7011      2.548      0.668      0.505      -3.296       6.698
# Production.transportation.and.material.moving.occupations      1.4630      2.549      0.574      0.566      -3.534       6.460
# SIRE_homogeneity                                             -22.1179      1.647    -13.430      0.000     -25.347     -18.889
# median_age                                                    -0.3954      0.043     -9.128      0.000      -0.480      -0.310
# Low.birthweight                                               57.0123     10.826      5.266      0.000      35.786      78.239
# Teen.births                                                    0.1099      0.014      8.065      0.000       0.083       0.137
# Children.in.single.parent.households                         -26.9720      2.387    -11.300      0.000     -31.652     -22.292
# Adult.smoking                                                 -0.6880      2.962     -0.232      0.816      -6.496       5.120
# Adult.obesity                                                  3.5082      5.734      0.612      0.541      -7.735      14.751
# Diabetes                                                      86.4210     11.880      7.274      0.000      63.127     109.715
# Sexually.transmitted.infections                               -0.0008      0.001     -0.777      0.437      -0.003       0.001
# Uninsured                                                     81.8205      4.224     19.372      0.000      73.539      90.102
# Unemployment                                                 -77.1828      6.272    -12.307      0.000     -89.480     -64.886
# Violent.crime                                                 -0.0022      0.001     -2.594      0.010      -0.004      -0.001
# Injury.deaths                                                  0.0169      0.008      2.090      0.037       0.001       0.033
# ==============================================================================
# Omnibus:                      114.800   Durbin-Watson:                   1.789
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              260.302
# Skew:                          -0.207   Prob(JB):                     2.99e-57
# Kurtosis:                       4.348   Cond. No.                     9.90e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.9e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
summary=lm.summary()
coefficient_df=pd.DataFrame(data=summary.tables[1].data[1:], columns=summary.tables[1].data[0])
coefficient_df['coef'] = coefficient_df['coef'].astype(float)
coefficient_df.sort_values(by = 'coef', ascending = False)
# Out:
#                                                              coef    std err  \
# 34                                           Diabetes   86.421000     11.880
# 36                                          Uninsured   81.820500      4.224
# 29                                    Low.birthweight   57.012300     10.826
# 19                                   Gini.Coefficient   12.078800      5.331
# 33                                      Adult.obesity    3.508200      5.734
# 21    Management.professional.and.related.occupations    1.910700      2.549
# 25  Construction.extraction.maintenance.and.repair...    1.701100      2.548
# 24           Farming.fishing.and.forestry.occupations    1.694100      2.549
# 23                       Sales.and.office.occupations    1.590300      2.548
# 26  Production.transportation.and.material.moving....    1.463000      2.549
# 22                                Service.occupations    1.311400      2.549
# 9                       White (Not Latino) Population    1.264000      2.659
# 11                         Native American Population    0.702500      2.659
# 12                          Asian American Population    0.648800      2.660
# 14                                  Latino Population    0.633400      2.659
# 13                                Other Race or Races    0.613800      2.661
# 10                        African American Population    0.497400      2.659
# 20  Child.Poverty.living.in.families.below.the.pov...    0.118600      0.051
# 30                                        Teen.births    0.109900      0.014
# 7                                   School Enrollment    0.025600      0.031
# 39                                      Injury.deaths    0.016900      0.008
# 17   Preschool.Enrollment.Ratio.enrolled.ages.3.and.4    0.001400      0.010
# 16                                   Total Population    0.000008   2.15e-06
# 8                                Median Earnings 2010   -0.000031   4.93e-05
# 2                                               Votes   -0.000032   5.42e-06
# 35                    Sexually.transmitted.infections   -0.000800      0.001
# 1                                           Precincts   -0.001100      0.002
# 4                        At Least High School Diploma   -0.001800      0.072
# 38                                      Violent.crime   -0.002200      0.001
# 3                       Less Than High School Diploma   -0.002200      0.078
# 15                 Children Under 6 Living in Poverty   -0.011600      0.025
# 28                                         median_age   -0.395400      0.043
# 18       Poverty.Rate.below.federal.poverty.threshold   -0.457900      0.077
# 5                         At Least Bachelors's Degree   -0.569200      0.060
# 32                                      Adult.smoking   -0.688000      2.962
# 6                                     Graduate Degree   -0.752600      0.101
# 27                                   SIRE_homogeneity  -22.117900      1.647
# 31               Children.in.single.parent.households  -26.972000      2.387
# 37                                       Unemployment  -77.182800      6.272
# 0                                               const -182.274200    367.339
#
#             t   P>|t|     [0.025     0.975]
# 34      7.274   0.000     63.127    109.715
# 36     19.372   0.000     73.539     90.102
# 29      5.266   0.000     35.786     78.239
# 19      2.266   0.024      1.627     22.531
# 33      0.612   0.541     -7.735     14.751
# 21      0.750   0.454     -3.087      6.908
# 25      0.668   0.505     -3.296      6.698
# 24      0.665   0.506     -3.304      6.692
# 23      0.624   0.533     -3.405      6.586
# 26      0.574   0.566     -3.534      6.460
# 22      0.515   0.607     -3.686      6.309
# 9       0.475   0.635     -3.949      6.477
# 11      0.264   0.792     -4.511      5.916
# 12      0.244   0.807     -4.566      5.864
# 14      0.238   0.812     -4.581      5.847
# 13      0.231   0.818     -4.604      5.832
# 10      0.187   0.852     -4.715      5.710
# 20      2.343   0.019      0.019      0.218
# 30      8.065   0.000      0.083      0.137
# 7       0.822   0.411     -0.035      0.087
# 39      2.090   0.037      0.001      0.033
# 17      0.141   0.888     -0.018      0.021
# 16      3.705   0.000   3.74e-06   1.22e-05
# 8      -0.634   0.526     -0.000   6.54e-05
# 2      -5.934   0.000  -4.28e-05  -2.16e-05
# 35     -0.777   0.437     -0.003      0.001
# 1      -0.548   0.584     -0.005      0.003
# 4      -0.025   0.980     -0.142      0.139
# 38     -2.594   0.010     -0.004     -0.001
# 3      -0.029   0.977     -0.155      0.150
# 15     -0.465   0.642     -0.060      0.037
# 28     -9.128   0.000     -0.480     -0.310
# 18     -5.984   0.000     -0.608     -0.308
# 5      -9.551   0.000     -0.686     -0.452
# 32     -0.232   0.816     -6.496      5.120
# 6      -7.448   0.000     -0.951     -0.554
# 27    -13.430   0.000    -25.347    -18.889
# 31    -11.300   0.000    -31.652    -22.292
# 37    -12.307   0.000    -89.480    -64.886
# 0      -0.496   0.620   -902.526    537.977

# %%
plt.scatter(lm.fittedvalues, lm.resid)

# %%
X = data_vote
y = data_vote['Republicans12_VoteShare']

corr = np.corrcoef(X,y)[0,1]

tval = corr * np.sqrt((len(X)-2)/(1- corr **2))
print(tval)

p = stats.t.sf(tval, len(X)-2)*2 #two tailed!
print(p)

# %%
stats.pearsonr(data_vote, data_vote['Republicans12_VoteShare'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-616b445c3c84> in <module>
# ----> 1 stats.pearsonr(data_vote, data_vote['Republicans12_VoteShare'])
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3403     # that the data type is at least 64 bit floating point.  It might have
#    3404     # more precision if the input is, for example, np.longdouble.
# -> 3405     dtype = type(1.0 + x[0] + y[0])
#    3406
#    3407     if n == 2:
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
