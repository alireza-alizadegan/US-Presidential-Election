# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
data = pd.read_csv('data_clean.csv')
data.head()
# Out:
#    Unnamed: 0     State   Fips                    County  Precincts    Votes  \
# 0           0  Arkansas   5043     Drew County, Arkansas       17.0   6590.0
# 1           1  Arkansas   5087  Madison County, Arkansas       20.0   6829.0
# 2           2   Georgia  13159    Jasper County, Georgia        3.0   6016.0
# 3           3  Colorado   8037    Eagle County, Colorado       30.0  22611.0
# 4           4   Georgia  13091     Dodge County, Georgia       16.0   6995.0
#
#    Less Than High School Diploma  At Least High School Diploma  \
# 0                           19.4                          80.6
# 1                           24.2                          75.8
# 2                           21.7                          78.3
# 3                           12.8                          87.2
# 4                           23.1                          76.9
#
#    At Least Bachelors's Degree  Graduate Degree  ...  Teen.births  \
# 0                         19.4              5.7  ...         47.7
# 1                         13.4              4.1  ...         49.0
# 2                         13.3              5.6  ...         54.1
# 3                         45.9             11.7  ...         41.3
# 4                         13.8              4.8  ...         64.0
#
#    Children.in.single.parent.households  Adult.smoking  Adult.obesity  \
# 0                                 0.429          0.181          0.323
# 1                                 0.179          0.304          0.328
# 2                                 0.381          0.210          0.298
# 3                                 0.204          0.095          0.132
# 4                                 0.453          0.189          0.358
#
#    Diabetes  Sexually.transmitted.infections  Uninsured  Unemployment  \
# 0     0.126                            747.3      0.197         0.108
# 1     0.135                            247.2      0.239         0.053
# 2     0.118                            324.1      0.239         0.096
# 3     0.036                            190.9      0.230         0.081
# 4     0.153                            497.9      0.208         0.115
#
#    Violent.crime  Injury.deaths
# 0         449.02           82.0
# 1         245.83           96.8
# 2         205.60           71.6
# 3         123.88           42.9
# 4         477.48           79.4
#
# [5 rows x 44 columns]

# %%
vote = pd.read_csv('votes_clean.csv')
vote.head()
# Out:
#    Unnamed: 0  Democrats_12(Votes)  Republicans_12(Votes)  \
# 0           0               2630.0                 3887.0
# 1           1               2099.0                 4263.0
# 2           2               1845.0                 4136.0
# 3           3              12792.0                 9411.0
# 4           4               2442.0                 5214.0
#
#    Democrats_16(Votes)  Republicans_16(Votes)  Democrats12_VoteShare  \
# 0               2364.0                 3967.0                  40.36
# 1               1587.0                 4917.0                  32.99
# 2               1544.0                 4353.0                  30.85
# 3              12652.0                 8153.0                  57.61
# 4               1836.0                 5021.0                  31.90
#
#    Republicans12_VoteShare  Democrats16_VoteShare  Republicans16_VoteShare
# 0                    59.64                  37.34                    62.66
# 1                    67.01                  24.40                    75.60
# 2                    69.15                  26.18                    73.82
# 3                    42.39                  60.81                    39.19
# 4                    68.10                  26.78                    73.22

# %%
data_vote = pd.merge(data, vote, on = 'Unnamed: 0')
data_vote.head(5)
# Out:
#    Unnamed: 0     State   Fips                    County  Precincts    Votes  \
# 0           0  Arkansas   5043     Drew County, Arkansas       17.0   6590.0
# 1           1  Arkansas   5087  Madison County, Arkansas       20.0   6829.0
# 2           2   Georgia  13159    Jasper County, Georgia        3.0   6016.0
# 3           3  Colorado   8037    Eagle County, Colorado       30.0  22611.0
# 4           4   Georgia  13091     Dodge County, Georgia       16.0   6995.0
#
#    Less Than High School Diploma  At Least High School Diploma  \
# 0                           19.4                          80.6
# 1                           24.2                          75.8
# 2                           21.7                          78.3
# 3                           12.8                          87.2
# 4                           23.1                          76.9
#
#    At Least Bachelors's Degree  Graduate Degree  ...  Violent.crime  \
# 0                         19.4              5.7  ...         449.02
# 1                         13.4              4.1  ...         245.83
# 2                         13.3              5.6  ...         205.60
# 3                         45.9             11.7  ...         123.88
# 4                         13.8              4.8  ...         477.48
#
#    Injury.deaths  Democrats_12(Votes)  Republicans_12(Votes)  \
# 0           82.0               2630.0                 3887.0
# 1           96.8               2099.0                 4263.0
# 2           71.6               1845.0                 4136.0
# 3           42.9              12792.0                 9411.0
# 4           79.4               2442.0                 5214.0
#
#    Democrats_16(Votes)  Republicans_16(Votes)  Democrats12_VoteShare  \
# 0               2364.0                 3967.0                  40.36
# 1               1587.0                 4917.0                  32.99
# 2               1544.0                 4353.0                  30.85
# 3              12652.0                 8153.0                  57.61
# 4               1836.0                 5021.0                  31.90
#
#    Republicans12_VoteShare  Democrats16_VoteShare  Republicans16_VoteShare
# 0                    59.64                  37.34                    62.66
# 1                    67.01                  24.40                    75.60
# 2                    69.15                  26.18                    73.82
# 3                    42.39                  60.81                    39.19
# 4                    68.10                  26.78                    73.22
#
# [5 rows x 52 columns]

# %%
data_vote.corrwith(data_vote['Republicans12_VoteShare'])
# Out:
# Unnamed: 0                                                    0.005362
# Fips                                                          0.046454
# Precincts                                                    -0.266277
# Votes                                                        -0.302003
# Less Than High School Diploma                                 0.049446
# At Least High School Diploma                                 -0.047965
# At Least Bachelors's Degree                                  -0.303216
# Graduate Degree                                              -0.369278
# School Enrollment                                            -0.132662
# Median Earnings 2010                                         -0.116098
# White (Not Latino) Population                                 0.437955
# African American Population                                  -0.392567
# Native American Population                                   -0.104147
# Asian American Population                                    -0.304657
# Other Race or Races                                          -0.092667
# Latino Population                                            -0.096990
# Children Under 6 Living in Poverty                           -0.115787
# Adults 65 and Older Living in Poverty                        -0.071574
# Total Population                                             -0.270416
# Preschool.Enrollment.Ratio.enrolled.ages.3.and.4             -0.271683
# Poverty.Rate.below.federal.poverty.threshold                 -0.164104
# Gini.Coefficient                                             -0.217965
# Child.Poverty.living.in.families.below.the.poverty.line      -0.135144
# Management.professional.and.related.occupations              -0.115862
# Service.occupations                                          -0.272234
# Sales.and.office.occupations                                 -0.195823
# Farming.fishing.and.forestry.occupations                      0.238850
# Construction.extraction.maintenance.and.repair.occupations    0.345326
# Production.transportation.and.material.moving.occupations     0.098097
# SIRE_homogeneity                                              0.281648
# median_age                                                    0.205948
# Low.birthweight                                              -0.153740
# Teen.births                                                   0.086154
# Children.in.single.parent.households                         -0.427325
# Adult.smoking                                                 0.124789
# Adult.obesity                                                 0.064553
# Diabetes                                                      0.075749
# Sexually.transmitted.infections                              -0.414017
# Uninsured                                                     0.258432
# Unemployment                                                 -0.328212
# Violent.crime                                                -0.299639
# Injury.deaths                                                 0.213762
# Democrats_12(Votes)                                          -0.329763
# Republicans_12(Votes)                                        -0.224541
# Democrats_16(Votes)                                          -0.326821
# Republicans_16(Votes)                                        -0.226416
# Democrats12_VoteShare                                        -1.000000
# Republicans12_VoteShare                                       1.000000
# Democrats16_VoteShare                                        -0.943883
# Republicans16_VoteShare                                       0.943883
# dtype: float64

# %%
data_vote.corrwith(data_vote['Republicans16_VoteShare'])
# Out:
# Unnamed: 0                                                    0.006771
# Fips                                                          0.051304
# Precincts                                                    -0.330111
# Votes                                                        -0.395448
# Less Than High School Diploma                                 0.058951
# At Least High School Diploma                                 -0.054349
# At Least Bachelors's Degree                                  -0.464169
# Graduate Degree                                              -0.517054
# School Enrollment                                            -0.167999
# Median Earnings 2010                                         -0.192509
# White (Not Latino) Population                                 0.552828
# African American Population                                  -0.461468
# Native American Population                                   -0.065390
# Asian American Population                                    -0.394287
# Other Race or Races                                          -0.107921
# Latino Population                                            -0.197589
# Children Under 6 Living in Poverty                           -0.078237
# Adults 65 and Older Living in Poverty                        -0.034175
# Total Population                                             -0.351670
# Preschool.Enrollment.Ratio.enrolled.ages.3.and.4             -0.304127
# Poverty.Rate.below.federal.poverty.threshold                 -0.143162
# Gini.Coefficient                                             -0.289031
# Child.Poverty.living.in.families.below.the.poverty.line      -0.105214
# Management.professional.and.related.occupations              -0.232779
# Service.occupations                                          -0.237250
# Sales.and.office.occupations                                 -0.265829
# Farming.fishing.and.forestry.occupations                      0.236012
# Construction.extraction.maintenance.and.repair.occupations    0.363026
# Production.transportation.and.material.moving.occupations     0.232372
# SIRE_homogeneity                                              0.438292
# median_age                                                    0.314474
# Low.birthweight                                              -0.190540
# Teen.births                                                   0.077503
# Children.in.single.parent.households                         -0.421455
# Adult.smoking                                                 0.235213
# Adult.obesity                                                 0.154736
# Diabetes                                                      0.129020
# Sexually.transmitted.infections                              -0.468603
# Uninsured                                                     0.168061
# Unemployment                                                 -0.300371
# Violent.crime                                                -0.370263
# Injury.deaths                                                 0.274245
# Democrats_12(Votes)                                          -0.404322
# Republicans_12(Votes)                                        -0.330903
# Democrats_16(Votes)                                          -0.408885
# Republicans_16(Votes)                                        -0.327154
# Democrats12_VoteShare                                        -0.943883
# Republicans12_VoteShare                                       0.943883
# Democrats16_VoteShare                                        -1.000000
# Republicans16_VoteShare                                       1.000000
# dtype: float64

# %%
X = data_vote
y = data_vote['Republicans12_VoteShare']

corr = np.corrcoef(X,y)[0,1]

tval = corr * np.sqrt((len(X)-2)/(1- corr **2))
print(tval)

p = stats.t.sf(tval, len(X)-2)*2 #two tailed!
print(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-c3a10e9b816b> in <module>
#       2 y = data_vote['Republicans12_VoteShare']
#       3
# ----> 4 corr = np.corrcoef(X,y)[0,1]
#       5
#       6 tval = corr * np.sqrt((len(X)-2)/(1- corr **2))
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2520         warnings.warn('bias and ddof have no effect and are deprecated',
#    2521                       DeprecationWarning, stacklevel=2)
# -> 2522     c = cov(x, y, rowvar)
#    2523     try:
#    2524         d = diag(c)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2384         if not rowvar and y.shape[0] != 1:
#    2385             y = y.T
# -> 2386         X = np.concatenate((X, y), axis=0)
#    2387
#    2388     if ddof is None:
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
stats.pearsonr(data_vote, data_vote['Republicans12_VoteShare'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-616b445c3c84> in <module>
# ----> 1 stats.pearsonr(data_vote, data_vote['Republicans12_VoteShare'])
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3403     # that the data type is at least 64 bit floating point.  It might have
#    3404     # more precision if the input is, for example, np.longdouble.
# -> 3405     dtype = type(1.0 + x[0] + y[0])
#    3406
#    3407     if n == 2:
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'
