# %% [markdown]
# # Analysis of US Presidential Election Data

# %% [markdown]
# This report presents analysis of US presidential election data for 2012 and 2016.
# The analysis is based on two spreadsheet datasets named *vote* and *data*. Both datasets are organized in a county-based manner meaning that every row includes information related to a specific county in US. The vote dataset includes number of votes for each of democrate and republican parties at each county in 2012 and 2016 elections. The data dataset includes census stats for each county including racial breakdown and economic status.

# %% [markdown]
# # Data cleaning

# %% [markdown]
# In this section *data* and *vote* datasets are inspected and cleaned. Data cleaning process for these datasets involved removing duplicate columns and handling missing values.

# %% [markdown]
# ## *Data* dataset

# %% [markdown]
# To prepare for data cleaning, overall data parameters is inspected. The shape of the *data* dataset is evaluated as:

# %%
import numpy as np
import pandas as pd
df_data = pd.read_csv('data.csv')
df_data.shape
# Out:
# (3141, 54)

# %% [markdown]
# This dataset includes 3141 rows corresponding to the number of counties in US and 54 columns of census information about these counties. A view of top 5 rows of this dataset are generated as follows:

# %%
pd.options.display.max_columns = 100
df_data.head()
# Out:
#       State  ST   Fips                    County  Precincts    Votes  \
# 0  Arkansas  AR   5043     Drew County, Arkansas       17.0   6590.0
# 1  Arkansas  AR   5087  Madison County, Arkansas       20.0   6829.0
# 2   Georgia  GA  13159    Jasper County, Georgia        3.0   6016.0
# 3  Colorado  CO   8037    Eagle County, Colorado       30.0  22611.0
# 4   Georgia  GA  13091     Dodge County, Georgia       16.0   6995.0
#
#    Less Than High School Diploma  At Least High School Diploma  \
# 0                           19.4                          80.6
# 1                           24.2                          75.8
# 2                           21.7                          78.3
# 3                           12.8                          87.2
# 4                           23.1                          76.9
#
#    At Least Bachelors's Degree  Graduate Degree  School Enrollment  \
# 0                         19.4              5.7               78.5
# 1                         13.4              4.1               76.4
# 2                         13.3              5.6               70.2
# 3                         45.9             11.7               64.1
# 4                         13.8              4.8               61.5
#
#    Median Earnings 2010  White (Not Latino) Population  \
# 0          21988.947300                          67.90
# 1          23365.948890                          92.00
# 2          25363.060950                          72.70
# 3          35484.543175                          68.40
# 4          26927.608255                          66.15
#
#    African American Population  Native American Population  \
# 0                        27.95                        0.15
# 1                         0.25                        1.25
# 2                        22.20                        0.40
# 3                         0.30                        0.25
# 4                        29.80                        0.15
#
#    Asian American Population  Other Race or Races  Latino Population  \
# 0                       0.55                 0.85               2.65
# 1                       0.30                 1.50               4.70
# 2                       0.10                 1.05               3.55
# 3                       1.15                 1.10              28.90
# 4                       0.45                 0.65               2.80
#
#    Children Under 6 Living in Poverty  Adults 65 and Older Living in Poverty  \
# 0                               34.15                                  14.40
# 1                               26.20                                  18.45
# 2                               17.60                                  17.95
# 3                               11.65                                   4.85
# 4                               20.65                                  20.60
#
#    Total Population  Preschool.Enrollment.Ratio.enrolled.ages.3.and.4  \
# 0             18604                                              73.5
# 1             15597                                              43.8
# 2             13744                                              36.5
# 3             51405                                              50.7
# 4             20745                                              41.5
#
#    Poverty.Rate.below.federal.poverty.threshold  Gini.Coefficient  \
# 0                                         23.45             0.469
# 1                                         18.20             0.446
# 2                                         18.05             0.451
# 3                                          9.40             0.464
# 4                                         21.15             0.464
#
#    Child.Poverty.living.in.families.below.the.poverty.line  \
# 0                                              36.95
# 1                                              25.15
# 2                                              27.60
# 3                                              12.05
# 4                                              23.70
#
#    Management.professional.and.related.occupations  Service.occupations  \
# 0                                            28.35                18.25
# 1                                            25.15                16.85
# 2                                            21.60                17.15
# 3                                            32.90                24.80
# 4                                            26.15                20.05
#
#    Sales.and.office.occupations  Farming.fishing.and.forestry.occupations  \
# 0                         20.15                                      3.60
# 1                         19.55                                      2.90
# 2                         22.60                                      4.35
# 3                         20.05                                      0.45
# 4                         22.00                                      1.60
#
#    Construction.extraction.maintenance.and.repair.occupations  \
# 0                                               9.40
# 1                                              16.20
# 2                                              15.10
# 3                                              15.50
# 4                                              11.35
#
#    Production.transportation.and.material.moving.occupations  White  Black  \
# 0                                              20.20          67.90  27.95
# 1                                              19.40          92.00   0.25
# 2                                              19.25          72.70  22.20
# 3                                               6.30          68.40   0.30
# 4                                              18.85          66.15  29.80
#
#    Hispanic  Asian  Amerindian  Other  White_Asian  SIRE_homogeneity  \
# 0      2.65   0.55        0.15   0.85        68.45          0.539968
# 1      4.70   0.30        1.25   1.50        92.30          0.849006
# 2      3.55   0.10        0.40   1.05        72.80          0.579201
# 3     28.90   1.15        0.25   1.10        69.55          0.551646
# 4      2.80   0.45        0.15   0.65        66.60          0.527235
#
#    median_age  Low.birthweight  Teen.births  \
# 0        36.8             0.10         47.7
# 1        38.5             0.07         49.0
# 2        38.1             0.09         54.1
# 3        33.4             0.09         41.3
# 4        37.7             0.12         64.0
#
#    Children.in.single.parent.households  Adult.smoking  Adult.obesity  \
# 0                                 0.429          0.181          0.323
# 1                                 0.179          0.304          0.328
# 2                                 0.381          0.210          0.298
# 3                                 0.204          0.095          0.132
# 4                                 0.453          0.189          0.358
#
#    Diabetes  Sexually.transmitted.infections  HIV.prevalence.rate  Uninsured  \
# 0     0.126                            747.3                 79.9      0.197
# 1     0.135                            247.2                131.3      0.239
# 2     0.118                            324.1                402.4      0.239
# 3     0.036                            190.9                133.7      0.230
# 4     0.153                            497.9                315.8      0.208
#
#    Unemployment  Violent.crime  Homicide.rate  Injury.deaths  Infant.mortality
# 0         0.108         449.02            NaN           82.0               NaN
# 1         0.053         245.83            NaN           96.8               NaN
# 2         0.096         205.60            NaN           71.6               NaN
# 3         0.081         123.88            NaN           42.9               3.5
# 4         0.115         477.48           8.11           79.4               NaN

# %% [markdown]
# At the first glance, it can be seen that the table involves many duplications in its columns. Following table shows
# names of duplicate columns:
#
#
# |State|White|Black|Asian|Hispanic|
# |-|-|-|-|-|
# |ST|White <br> (Not Latino) <br> Population|African <br> American <br> Population|Asian <br> American <br> Population|Latino <br> Population|
#
# To evaluate the potential of each column for removal, number of unique items in
# each of these columns are evaluated to ensure that the column with most complete
# information is retained.

# %%
df_data[['State','ST', 'Fips','County', 'Precincts']].nunique()
# Out:
# State          51
# ST             51
# Fips         3141
# County       3141
# Precincts     303
# dtype: int64

# %% [markdown]
# Number of unique items in *State* and *ST* are both equal to number states in US. Therefore, there is no difference between the two columns in terms of completeness of information; however, *State* column has more information on state names, so it is kept and *ST* is removed.
# Number of unique counties, FIPS codes, and precincts are retrieved as well to valuidate the accuracy of information in these columns.

# %% [markdown]
# For numerical columns, statistical information for duplicate columns are calculated as:

# %%
df_data.describe()[['White (Not Latino) Population', 'White', 'African American Population', 'Black', 'Asian American Population', 'Asian', 'Latino Population', 'Hispanic']]
# Out:
#        White (Not Latino) Population        White  \
# count                    3141.000000  3141.000000
# mean                       78.778908    78.778908
# std                        19.625220    19.625220
# min                         2.500000     2.500000
# 25%                        67.700000    67.700000
# 50%                        86.350000    86.350000
# 75%                        94.300000    94.300000
# max                        99.200000    99.200000
#
#        African American Population        Black  Asian American Population  \
# count                  3141.000000  3141.000000                3141.000000
# mean                      8.752642     8.752642                   1.106129
# std                      14.384847    14.384847                   2.435244
# min                       0.000000     0.000000                   0.000000
# 25%                       0.400000     0.400000                   0.250000
# 50%                       1.900000     1.900000                   0.450000
# 75%                       9.900000     9.900000                   1.000000
# max                      86.100000    86.100000                  42.700000
#
#              Asian  Latino Population     Hispanic
# count  3141.000000        3141.000000  3141.000000
# mean      1.106129           7.904760     7.904760
# std       2.435244          12.955106    12.955106
# min       0.000000           0.000000     0.000000
# 25%       0.250000           1.450000     1.450000
# 50%       0.450000           2.950000     2.950000
# 75%       1.000000           7.800000     7.800000
# max      42.700000          97.150000    97.150000

# %% [markdown]
# For all four groups, all eight of their statistical information matches perfectly meaning either one can be removed from the dataset
# as follows:

# %%
df_data.drop(['ST', 'White (Not Latino) Population', 'African American Population', 'Asian American Population', 'Latino Population'], axis = 1, inplace = True)

# %% [markdown]
# To clean null values in this table, percentage of null values in each column is evaluated as:

# %%
np.mean(df_data.isna(),axis=0)*100
# Out:
# State                                                          0.000000
# Fips                                                           0.000000
# County                                                         0.000000
# Precincts                                                      1.018784
# Votes                                                          1.018784
# Less Than High School Diploma                                  0.000000
# At Least High School Diploma                                   0.000000
# At Least Bachelors's Degree                                    0.000000
# Graduate Degree                                                0.000000
# School Enrollment                                              0.000000
# Median Earnings 2010                                           0.000000
# Native American Population                                     0.000000
# Other Race or Races                                            0.000000
# Children Under 6 Living in Poverty                             0.000000
# Adults 65 and Older Living in Poverty                          0.000000
# Total Population                                               0.000000
# Preschool.Enrollment.Ratio.enrolled.ages.3.and.4               0.254696
# Poverty.Rate.below.federal.poverty.threshold                   0.000000
# Gini.Coefficient                                               0.000000
# Child.Poverty.living.in.families.below.the.poverty.line        0.031837
# Management.professional.and.related.occupations                0.000000
# Service.occupations                                            0.000000
# Sales.and.office.occupations                                   0.000000
# Farming.fishing.and.forestry.occupations                       0.000000
# Construction.extraction.maintenance.and.repair.occupations     0.000000
# Production.transportation.and.material.moving.occupations      0.000000
# White                                                          0.000000
# Black                                                          0.000000
# Hispanic                                                       0.000000
# Asian                                                          0.000000
# Amerindian                                                     0.000000
# Other                                                          0.000000
# White_Asian                                                    0.000000
# SIRE_homogeneity                                               0.000000
# median_age                                                     0.000000
# Low.birthweight                                                7.226998
# Teen.births                                                    3.151862
# Children.in.single.parent.households                           0.222859
# Adult.smoking                                                 13.849093
# Adult.obesity                                                  0.159185
# Diabetes                                                       0.159185
# Sexually.transmitted.infections                                6.017192
# HIV.prevalence.rate                                           26.138173
# Uninsured                                                      0.191022
# Unemployment                                                   0.191022
# Violent.crime                                                  5.985355
# Homicide.rate                                                 60.171920
# Injury.deaths                                                  9.455587
# Infant.mortality                                              54.982490
# dtype: float64

# %% [markdown]
# *HIV.prevalence.rate* and *Homicide.rate* have more than 50% null values and *Infant.mortality* has more than 25%. Furthermore,
# information in these topics might not have significant influence on election results. Therefore, these three columns are dropped out
# of the dataset as follows:

# %%
df_data.drop(['HIV.prevalence.rate','Homicide.rate','Infant.mortality'], axis = 1, inplace = True)

# %% [markdown]
# As rest of the null values are in numerical columns, mean value of each column is assigned for missing data in that column.

# %%
df_data.fillna(df_data.mean(), inplace=True)

# %% [markdown]
# To confirm that there are no longer any null values in the table, table information is retrieved as follows:

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Data columns (total 46 columns):
# State                                                         3141 non-null object
# Fips                                                          3141 non-null int64
# County                                                        3141 non-null object
# Precincts                                                     3141 non-null float64
# Votes                                                         3141 non-null float64
# Less Than High School Diploma                                 3141 non-null float64
# At Least High School Diploma                                  3141 non-null float64
# At Least Bachelors's Degree                                   3141 non-null float64
# Graduate Degree                                               3141 non-null float64
# School Enrollment                                             3141 non-null float64
# Median Earnings 2010                                          3141 non-null float64
# Native American Population                                    3141 non-null float64
# Other Race or Races                                           3141 non-null float64
# Children Under 6 Living in Poverty                            3141 non-null float64
# Adults 65 and Older Living in Poverty                         3141 non-null float64
# Total Population                                              3141 non-null int64
# Preschool.Enrollment.Ratio.enrolled.ages.3.and.4              3141 non-null float64
# Poverty.Rate.below.federal.poverty.threshold                  3141 non-null float64
# Gini.Coefficient                                              3141 non-null float64
# Child.Poverty.living.in.families.below.the.poverty.line       3141 non-null float64
# Management.professional.and.related.occupations               3141 non-null float64
# Service.occupations                                           3141 non-null float64
# Sales.and.office.occupations                                  3141 non-null float64
# Farming.fishing.and.forestry.occupations                      3141 non-null float64
# Construction.extraction.maintenance.and.repair.occupations    3141 non-null float64
# Production.transportation.and.material.moving.occupations     3141 non-null float64
# White                                                         3141 non-null float64
# Black                                                         3141 non-null float64
# Hispanic                                                      3141 non-null float64
# Asian                                                         3141 non-null float64
# Amerindian                                                    3141 non-null float64
# Other                                                         3141 non-null float64
# White_Asian                                                   3141 non-null float64
# SIRE_homogeneity                                              3141 non-null float64
# median_age                                                    3141 non-null float64
# Low.birthweight                                               3141 non-null float64
# Teen.births                                                   3141 non-null float64
# Children.in.single.parent.households                          3141 non-null float64
# Adult.smoking                                                 3141 non-null float64
# Adult.obesity                                                 3141 non-null float64
# Diabetes                                                      3141 non-null float64
# Sexually.transmitted.infections                               3141 non-null float64
# Uninsured                                                     3141 non-null float64
# Unemployment                                                  3141 non-null float64
# Violent.crime                                                 3141 non-null float64
# Injury.deaths                                                 3141 non-null float64
# dtypes: float64(42), int64(2), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# Finally, an overall validation of the data is performed by comparing the summary statistics with results of the internet search
# for a number of facts about US.

# %%
df_data.describe()
# Out:
#               Fips    Precincts         Votes  Less Than High School Diploma  \
# count   3141.00000  3141.000000  3.141000e+03                    3141.000000
# mean   30406.52149    54.940495  4.178247e+04                      16.874514
# std    15156.09339   172.042846  1.128778e+05                       7.349563
# min     1001.00000     1.000000  6.400000e+01                       0.700000
# 25%    18181.00000    11.000000  4.902000e+03                      11.400000
# 50%    29179.00000    20.000000  1.117700e+04                      15.400000
# 75%    45083.00000    39.000000  2.990200e+04                      21.600000
# max    56045.00000  4988.000000  2.652072e+06                      52.100000
#
#        At Least High School Diploma  At Least Bachelors's Degree  \
# count                   3141.000000                  3141.000000
# mean                      83.045893                    19.013419
# std                        7.533330                     8.646941
# min                       29.900000                     3.700000
# 25%                       78.400000                    13.100000
# 50%                       84.600000                    16.900000
# 75%                       88.600000                    22.600000
# max                       99.300000                    71.000000
#
#        Graduate Degree  School Enrollment  Median Earnings 2010  \
# count      3141.000000        3141.000000           3141.000000
# mean          6.449682          74.953932          25463.387576
# std           3.849162           5.261211           5078.837873
# min           0.000000           0.000000              0.000000
# 25%           4.000000          72.300000          22332.413650
# 50%           5.300000          75.150000          24830.888890
# 75%           7.700000          77.950000          27548.556510
# max          40.600000         100.000000          56674.350795
#
#        Native American Population  Other Race or Races  \
# count                 3141.000000          3141.000000
# mean                     1.819596             1.637822
# std                      7.418349             1.901044
# min                      0.000000             0.000000
# 25%                      0.200000             0.900000
# 50%                      0.300000             1.300000
# 75%                      0.650000             1.850000
# max                     92.050000            57.200000
#
#        Children Under 6 Living in Poverty  \
# count                         3141.000000
# mean                            24.818609
# std                             11.889270
# min                              0.000000
# 25%                             16.400000
# 50%                             23.750000
# 75%                             31.700000
# max                             79.650000
#
#        Adults 65 and Older Living in Poverty  Total Population  \
# count                            3141.000000      3.141000e+03
# mean                               11.468386      9.711190e+04
# std                                 5.479738      3.111593e+05
# min                                 0.000000      8.100000e+01
# 25%                                 7.600000      1.103000e+04
# 50%                                10.250000      2.563100e+04
# 75%                                14.150000      6.589400e+04
# max                                45.500000      9.801950e+06
#
#        Preschool.Enrollment.Ratio.enrolled.ages.3.and.4  \
# count                                       3141.000000
# mean                                          43.063837
# std                                           14.507635
# min                                            0.000000
# 25%                                           34.700000
# 50%                                           43.100000
# 75%                                           51.700000
# max                                          100.000000
#
#        Poverty.Rate.below.federal.poverty.threshold  Gini.Coefficient  \
# count                                   3141.000000        3141.00000
# mean                                      15.447246           0.43144
# std                                        6.384713           0.03661
# min                                        0.000000           0.20700
# 25%                                       11.000000           0.40700
# 50%                                       14.650000           0.42900
# 75%                                       18.950000           0.45300
# max                                       52.250000           0.64500
#
#        Child.Poverty.living.in.families.below.the.poverty.line  \
# count                                        3141.000000
# mean                                           21.091720
# std                                             9.567612
# min                                             0.000000
# 25%                                            14.150000
# 50%                                            20.200000
# 75%                                            26.550000
# max                                            64.300000
#
#        Management.professional.and.related.occupations  Service.occupations  \
# count                                      3141.000000          3141.000000
# mean                                         29.855237            17.443235
# std                                           6.432767             3.514847
# min                                           9.050000             0.000000
# 25%                                          25.500000            15.200000
# 50%                                          28.800000            17.150000
# 75%                                          33.150000            19.250000
# max                                          66.550000            39.500000
#
#        Sales.and.office.occupations  Farming.fishing.and.forestry.occupations  \
# count                   3141.000000                               3141.000000
# mean                      22.828797                                  2.116237
# std                        3.484825                                  2.595179
# min                        5.400000                                  0.000000
# 25%                       20.750000                                  0.550000
# 50%                       23.000000                                  1.250000
# 75%                       25.350000                                  2.700000
# max                       38.350000                                 29.250000
#
#        Construction.extraction.maintenance.and.repair.occupations  \
# count                                        3141.000000
# mean                                           11.521665
# std                                             3.370997
# min                                             0.000000
# 25%                                             9.250000
# 50%                                            11.100000
# 75%                                            13.350000
# max                                            28.750000
#
#        Production.transportation.and.material.moving.occupations        White  \
# count                                        3141.000000          3141.000000
# mean                                           16.235721            78.778908
# std                                             6.114629            19.625220
# min                                             1.300000             2.500000
# 25%                                            11.650000            67.700000
# 50%                                            15.750000            86.350000
# 75%                                            20.150000            94.300000
# max                                            69.550000            99.200000
#
#              Black     Hispanic        Asian   Amerindian        Other  \
# count  3141.000000  3141.000000  3141.000000  3141.000000  3141.000000
# mean      8.752642     7.904760     1.106129     1.819596     1.637822
# std      14.384847    12.955106     2.435244     7.418349     1.901044
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.400000     1.450000     0.250000     0.200000     0.900000
# 50%       1.900000     2.950000     0.450000     0.300000     1.300000
# 75%       9.900000     7.800000     1.000000     0.650000     1.850000
# max      86.100000    97.150000    42.700000    92.050000    57.200000
#
#        White_Asian  SIRE_homogeneity   median_age  Low.birthweight  \
# count  3141.000000       3141.000000  3141.000000      3141.000000
# mean     79.885037          0.717665    39.862846         0.083493
# std      19.132100          0.185027     4.922651         0.020290
# min       2.650000          0.227734    18.000000         0.030000
# 25%      69.450000          0.543010    37.100000         0.070000
# 50%      87.350000          0.755945    39.900000         0.080000
# 75%      94.900000          0.890220    42.800000         0.090000
# max      99.250000          0.984084    62.500000         0.180000
#
#        Teen.births  Children.in.single.parent.households  Adult.smoking  \
# count  3141.000000                           3141.000000    3141.000000
# mean     44.406345                              0.315941       0.212722
# std      19.721208                              0.102989       0.058563
# min       4.100000                              0.000000       0.031000
# 25%      29.500000                              0.249000       0.176000
# 50%      43.500000                              0.308000       0.212722
# 75%      56.500000                              0.369000       0.242000
# max     130.400000                              0.787000       0.511000
#
#        Adult.obesity     Diabetes  Sexually.transmitted.infections  \
# count    3141.000000  3141.000000                      3141.000000
# mean        0.305523     0.107103                       354.269682
# std         0.042393     0.022511                       264.761666
# min         0.131000     0.033000                        37.400000
# 25%         0.283000     0.092000                       187.300000
# 50%         0.307000     0.106000                       285.100000
# 75%         0.331000     0.122000                       426.200000
# max         0.479000     0.194000                      2754.400000
#
#          Uninsured  Unemployment  Violent.crime  Injury.deaths
# count  3141.000000   3141.000000    3141.000000    3141.000000
# mean      0.179860      0.077045     257.055923      76.112553
# std       0.054713      0.027654     201.253476      23.412340
# min       0.031000      0.008000       0.000000      23.300000
# 25%       0.140000      0.058000     120.440000      60.800000
# 50%       0.177000      0.075000     215.630000      75.600000
# 75%       0.215000      0.093000     327.700000      86.500000
# max       0.460000      0.283000    1989.540000     320.900000

# %% [markdown]
# Results of internet search for a number of facts about US
#
# |Median Earning|Gini Coefficient|Median Age|Adult Smoking|Adult Obesity|Diabetes|STI|Unemployment|
# |-|-|-|-|-|-|-|-|
# |$31099|0.49|38.1|15.1|0.369|0.094|0.089|0.036|

# %% [markdown]
# Comparing the results in two table shows that the data are within expected quantitative range.

# %% [markdown]
# ## *Vote* dataset

# %% [markdown]
# The shape of the *vote* dataset is evaluated as:

# %%
df_vote = pd.read_csv('votes.csv')
df_vote.shape
# Out:
# (3141, 6)

# %% [markdown]
# It is validated that this dataset includes information for all counties. Furthermore, it consists of 6 clomuns related to elections.
# To obtained an insight about each column, head of the table is shown as follows:

# %%
df_vote = pd.read_csv('votes.csv')
df_vote.head()
# Out:
#    Unnamed: 0  Democrats_12(Votes)  Republicans_12(Votes)  \
# 0           0               2630.0                 3887.0
# 1           1               2099.0                 4263.0
# 2           2               1845.0                 4136.0
# 3           3              12792.0                 9411.0
# 4           4               2442.0                 5214.0
#
#    Democrats_16(Votes)  Republicans_16(Votes)   Fips
# 0               2364.0                 3967.0   5043
# 1               1587.0                 4917.0   5087
# 2               1544.0                 4353.0  13159
# 3              12652.0                 8153.0   8037
# 4               1836.0                 5021.0  13091

# %% [markdown]
# Columns contain information about break down of democrat and republican votes in 2012 and 2016 as well as the FIPS code of each county.
# There is a duplicated index column named *Unnamed: 0* which is dropped out of the table as follows:

# %%
df_vote.drop(['Unnamed: 0'], axis = 1, inplace = True)
display(df_vote)
# Out:
#       Democrats_12(Votes)  Republicans_12(Votes)  Democrats_16(Votes)  \
# 0                  2630.0                 3887.0               2364.0
# 1                  2099.0                 4263.0               1587.0
# 2                  1845.0                 4136.0               1544.0
# 3                 12792.0                 9411.0              12652.0
# 4                  2442.0                 5214.0               1836.0
# ...                   ...                    ...                  ...
# 3136              62388.0               105176.0              56700.0
# 3137               7062.0                13633.0               4537.0
# 3138              81464.0                59405.0              64958.0
# 3139               6144.0                 8162.0               5455.0
# 3140                115.0                 1082.0                 70.0
#
#       Republicans_16(Votes)   Fips
# 0                    3967.0   5043
# 1                    4917.0   5087
# 2                    4353.0  13159
# 3                    8153.0   8037
# 4                    5021.0  13091
# ...                     ...    ...
# 3136               104441.0  39017
# 3137                15586.0  39091
# 3138                65346.0  39093
# 3139                 9992.0  40021
# 3140                  962.0  40025
#
# [3141 rows x 5 columns]

# %% [markdown]
# To obtain an insight about the number of null values in the table, percentage of null values in each column is obtained as:

# %%
np.mean(df_vote.isna(),axis=0)*100
# Out:
# Democrats_12(Votes)      0.986947
# Republicans_12(Votes)    0.986947
# Democrats_16(Votes)      1.018784
# Republicans_16(Votes)    1.018784
# Fips                     0.000000
# dtype: float64

# %% [markdown]
# The results show that only a small percentage of data is missing. Therefor, they are replaced by mean value of each column as follows:

# %%
df_vote.fillna(df_vote.mean(), inplace=True)

# %% [markdown]
# To confirm that there are no longer any null values in the table, table information is retrieved as follows:

# %%
df_vote.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3141 entries, 0 to 3140
# Data columns (total 5 columns):
# Democrats_12(Votes)      3141 non-null float64
# Republicans_12(Votes)    3141 non-null float64
# Democrats_16(Votes)      3141 non-null float64
# Republicans_16(Votes)    3141 non-null float64
# Fips                     3141 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 122.8 KB

# %% [markdown]
# Four additional column is added to the end of this table calculating percentages of democrat and republican voters in 2012 and 2016
# as follows:

# %%
df_vote['Percent_Democrats_12'] = df_vote['Democrats_12(Votes)']/(df_vote['Democrats_12(Votes)']+df_vote['Republicans_12(Votes)'])*100
df_vote['Percent_Republicans_12'] = df_vote['Republicans_12(Votes)']/(df_vote['Democrats_12(Votes)']+df_vote['Republicans_12(Votes)'])*100
df_vote['Percent_Democrats_16'] = df_vote['Democrats_16(Votes)']/(df_vote['Democrats_16(Votes)']+df_vote['Republicans_16(Votes)'])*100
df_vote['Percent_Republicans_16'] = df_vote['Republicans_16(Votes)']/(df_vote['Democrats_16(Votes)']+df_vote['Republicans_16(Votes)'])*100
df_vote
# Out:
#       Democrats_12(Votes)  Republicans_12(Votes)  Democrats_16(Votes)  \
# 0                  2630.0                 3887.0               2364.0
# 1                  2099.0                 4263.0               1587.0
# 2                  1845.0                 4136.0               1544.0
# 3                 12792.0                 9411.0              12652.0
# 4                  2442.0                 5214.0               1836.0
# ...                   ...                    ...                  ...
# 3136              62388.0               105176.0              56700.0
# 3137               7062.0                13633.0               4537.0
# 3138              81464.0                59405.0              64958.0
# 3139               6144.0                 8162.0               5455.0
# 3140                115.0                 1082.0                 70.0
#
#       Republicans_16(Votes)   Fips  Percent_Democrats_12  \
# 0                    3967.0   5043             40.355992
# 1                    4917.0   5087             32.992770
# 2                    4353.0  13159             30.847684
# 3                    8153.0   8037             57.613836
# 4                    5021.0  13091             31.896552
# ...                     ...    ...                   ...
# 3136               104441.0  39017             37.232341
# 3137                15586.0  39091             34.124185
# 3138                65346.0  39093             57.829615
# 3139                 9992.0  40021             42.947015
# 3140                  962.0  40025              9.607352
#
#       Percent_Republicans_12  Percent_Democrats_16  Percent_Republicans_16
# 0                  59.644008             37.340073               62.659927
# 1                  67.007230             24.400369               75.599631
# 2                  69.152316             26.182805               73.817195
# 3                  42.386164             60.812305               39.187695
# 4                  68.103448             26.775558               73.224442
# ...                      ...                   ...                     ...
# 3136               62.767659             35.186576               64.813424
# 3137               65.875815             22.546340               77.453660
# 3138               42.170385             49.851117               50.148883
# 3139               57.052985             35.314301               64.685699
# 3140               90.392648              6.782946               93.217054
#
# [3141 rows x 9 columns]

# %% [markdown]
# # Exploratory data analytics (EDA)

# %% [markdown]
# To obtain an insight about the data in these tables, five column are selected and plotted.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize']=(8.0, 6.0)
import matplotlib.gridspec as gridspec
import seaborn as sns

# %% [markdown]
# The first column is *State*. This column shows the state to which the specific county is associated to. This column is categorical
# and therefore it is plotted as a bar chart.

# %%
sns.countplot(df_data['State'])
plt.title('Number of counties in each state')
plt.xlabel('State')
plt.ylabel('Number of counties')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Texas, Georgia, and Virgina have the largest number of counties.

# %% [markdown]
# Next, a number of numerical columns have been selected and plotted on histograms. First, two relatively natural parameters, namely age and income, are chosen.

# %%
# histogram for median age 
plt.hist(df_data['median_age'], 30)
plt.title('Median age in counties')
plt.xlabel('Median age')
plt.ylabel('Number of counties')
plt.show()

# histogram for median earnings 
plt.hist(df_data['Median Earnings 2010'], 30)
plt.title('Median earnings in counties')
plt.xlabel('Median earnings')
plt.ylabel('Number of counties')
plt.show()

# %% [markdown]
# The figure shows that these parameters are normally distributed among counties.

# %% [markdown]
# Next, two other columns, namely white population and unemployment rate and chosen and plotted as follows:

# %%
# histogram for population of white people
plt.hist(df_data['White'], 30)
plt.title('Number of white people in counties')
plt.xlabel('Number of white people')
plt.ylabel('Number of counties')
plt.show()

# histogram for unemployment rate
plt.hist(df_data['Unemployment'], 30)
plt.title('Unemployment rate in counties')
plt.xlabel('Unemployment rate')
plt.ylabel('Number of counties')
plt.show()

# %% [markdown]
# The results show that these parameters are not as perfectly normally distributed as the ones before because they are not perfectly
# natural parameters.
